# %% [markdown]
# # 02 - Preprocesamiento de Texto
#
# Limpieza, tokenización, eliminación de stopwords y stemming.
#
# **Objetivos:**
# - Limpiar el texto (minúsculas, caracteres especiales)
# - Tokenizar en palabras
# - Remover stopwords en español
# - Aplicar stemming

# %%
import pandas as pd
import sys
sys.path.append('../')

from src.preprocesamiento import procesar_corpus, procesar_documento

# %% [markdown]
# ## 1. Cargar datos originales

# %%
# Cargar el CSV
df = pd.read_csv('../data/raw/encuesta.csv')
print(f"Total de documentos: {len(df)}")
print(f"\nPrimer documento original:")
print(df.iloc[0])

# %% [markdown]
# ## 2. Procesar documentos

# %%
# Seleccionar la columna de opiniones
# (ajusta el nombre según tu dataset)
# opiniones = df['columna_opinion'].astype(str).tolist()

# Ejemplo de procesamiento de un documento
# documento_ejemplo = opiniones[0]
# tokens_procesados = procesar_documento(documento_ejemplo)
# print(f"Original: {documento_ejemplo}")
# print(f"\nProcesado: {tokens_procesados}")

# %% [markdown]
# ## 3. Procesar todo el corpus

# %%
# corpus_procesado = procesar_corpus(opiniones)
# print(f"Corpus procesado: {len(corpus_procesado)} documentos")
# print(f"\nPrimer documento procesado: {corpus_procesado[0][:10]}...")

# %% [markdown]
# ## 4. Guardar corpus procesado

# %%
# import pickle
# 
# # Guardar corpus procesado
# with open('../data/processed/corpus_procesado.pkl', 'wb') as f:
#     pickle.dump(corpus_procesado, f)
# 
# # Guardar también como lista de strings
# corpus_strings = [' '.join(tokens) for tokens in corpus_procesado]
# df_procesado = pd.DataFrame({'opiniones_procesadas': corpus_strings})
# df_procesado.to_csv('../data/processed/corpus_procesado.csv', index=False)
# 
# print("✅ Corpus guardado en data/processed/")
